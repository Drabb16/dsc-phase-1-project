# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd
import numpy as np

# %%
basics = pd.read_csv('zippeddata/imdb.title.basics.csv.gz')
ratings = pd.read_csv('zippeddata/imdb.title.ratings.csv.gz')
gross = pd.read_csv('zippeddata/bom.movie_gross.csv.gz')
popularity = pd.read_csv('zippeddata/tmdb.movies.csv.gz')
budgets = pd.read_csv('zippeddata/tn.movie_budgets.csv.gz')

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
basics.describe()
# Out:
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %% [markdown]
# Diving first into genre popularity and revenue.

# %%
basics['genres'].value_counts()[:10]
# Out:
# Documentary              32185
# Drama                    21486
# Comedy                    9177
# Horror                    4372
# Comedy,Drama              3519
# Thriller                  3046
# Action                    2219
# Biography,Documentary     2115
# Drama,Romance             2079
# Comedy,Drama,Romance      1558
# Name: genres, dtype: int64

# %%
popularity.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
popularity['genre_ids'].describe()
# Out:
# count     26517
# unique     2477
# top        [99]
# freq       3700
# Name: genre_ids, dtype: object

# %%
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets['worldwide_gross'] = budgets['worldwide_gross'].str.replace(',', '')
budgets['worldwide_gross'] = budgets['worldwide_gross'].str.replace('$', '')
budgets['production_budget'] = budgets['production_budget'].str.replace(',', '')
budgets['production_budget'] = budgets['production_budget'].str.replace('$', '')
budgets.drop(columns = ['release_date'])
# Out:
#       id                                        movie production_budget  \
# 0      1                                       Avatar         425000000
# 1      2  Pirates of the Caribbean: On Stranger Tides         410600000
# 2      3                                 Dark Phoenix         350000000
# 3      4                      Avengers: Age of Ultron         330600000
# 4      5            Star Wars Ep. VIII: The Last Jedi         317000000
# ...   ..                                          ...               ...
# 5777  78                                       Red 11              7000
# 5778  79                                    Following              6000
# 5779  80                Return to the Land of Wonders              5000
# 5780  81                         A Plague So Pleasant              1400
# 5781  82                            My Date With Drew              1100
#
#      domestic_gross worldwide_gross
# 0      $760,507,625      2776345279
# ...

# %%
print(budgets['worldwide_gross'])
# Out:
# 0       2776345279
# 1       1045663875
# 2        149762350
# 3       1403013963
# 4       1316721747
#            ...
# 5777             0
# 5778        240495
# 5779          1338
# 5780             0
# 5781        181041
# Name: worldwide_gross, Length: 5782, dtype: object

# %%
budgets['worldwide_gross'].value_counts()
# Out:
# 0           367
# 8000000       9
# 2000000       6
# 7000000       6
# 10000000      4
#            ...
# 72571864      1
# 1919197       1
# 32653000      1
# 4984663       1
# 261364        1
# Name: worldwide_gross, Length: 5356, dtype: int64

# %%
budgets['production_budget'].value_counts()
# Out:
# 20000000    231
# 10000000    212
# 30000000    177
# 15000000    173
# 25000000    171
#            ...
# 2627000       1
# 8470000       1
# 1577000       1
# 168000        1
# 15250000      1
# Name: production_budget, Length: 509, dtype: int64

# %%
wwg_list = budgets['worldwide_gross'].tolist()

# %%
wwg_list
# Out:
# ['2776345279',
#  '1045663875',
#  '149762350',
#  '1403013963',
#  '1316721747',
#  '2053311220',
#  '2048134200',
#  '963420425',
#  '655945209',
#  '879620923',
#  '1084439099',
#  '393151347',
#  '260002115',
#  '282778100',
#  '586477240',
#  '894860230',
#  '1140069413',
#  '867500281',
#  '1017003568',
#  '935213767',
#  '960366855',
#  '945577621',
#  '1234846267',
#  '374085065',
#  '788241137',
#  '591692078',
#  '1517935897',
#  '1066215812',
#  '667999518',
#  '417341288',
#  '757890267',
#  '313477717',
#  '602893340',
#  '1648854864',
#  '654213485',
#  '836519699',
#  '1104039076',
#  '459260946',
#  '322459006',
#  '550517357',
#  '367262558',
#  '1348258224',
#  '2208208395',
#  '1242520711',
#  '1049102856',
#  '1021215193',
#  '1068879522',
#  '1215392272',
#  '862316233',
#  '795110670',
#  '1025491110',
#  '1110526981',
#  '743588329',
#  '490359051',
#  '747862775',
#  '708996336',
#  '560155383',
#  '400062763',
#  '757677748',
#  '652220086',
#  '365491792',
# ...

# %%
pb_list = budgets['production_budget'].tolist()

# %%
pb_list = list(map(int, pb_list))

# %%
pb_list
# Out:
# [425000000,
#  410600000,
#  350000000,
#  330600000,
#  317000000,
#  306000000,
#  300000000,
#  300000000,
#  300000000,
#  300000000,
#  275000000,
#  275000000,
#  275000000,
#  275000000,
#  260000000,
#  258000000,
#  250000000,
#  250000000,
#  250000000,
#  250000000,
#  250000000,
#  250000000,
#  250000000,
#  232000000,
#  230000000,
#  230000000,
#  225000000,
#  225000000,
#  225000000,
#  225000000,
#  220000000,
#  220000000,
#  217000000,
#  215000000,
#  215000000,
#  210000000,
#  210000000,
#  210000000,
#  210000000,
#  207000000,
#  205000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  200000000,
#  195000000,
#  195000000,
#  195000000,
#  190000000,
#  190000000,
#  190000000,
#  190000000,
#  190000000,
# ...

# %%
wwg_list = list(map(int, wwg_list))

# %%
wwg_list
# Out:
# [2776345279,
#  1045663875,
#  149762350,
#  1403013963,
#  1316721747,
#  2053311220,
#  2048134200,
#  963420425,
#  655945209,
#  879620923,
#  1084439099,
#  393151347,
#  260002115,
#  282778100,
#  586477240,
#  894860230,
#  1140069413,
#  867500281,
#  1017003568,
#  935213767,
#  960366855,
#  945577621,
#  1234846267,
#  374085065,
#  788241137,
#  591692078,
#  1517935897,
#  1066215812,
#  667999518,
#  417341288,
#  757890267,
#  313477717,
#  602893340,
#  1648854864,
#  654213485,
#  836519699,
#  1104039076,
#  459260946,
#  322459006,
#  550517357,
#  367262558,
#  1348258224,
#  2208208395,
#  1242520711,
#  1049102856,
#  1021215193,
#  1068879522,
#  1215392272,
#  862316233,
#  795110670,
#  1025491110,
#  1110526981,
#  743588329,
#  490359051,
#  747862775,
#  708996336,
#  560155383,
#  400062763,
#  757677748,
#  652220086,
#  365491792,
#  219535492,
#  336359676,
#  1123790543,
#  409953905,
#  197687603,
#  1518722794,
#  467381584,
#  531514650,
# ...

# %%
wwg_array = np.array(wwg_list)
pb_array = np.array(pb_list)

# %%
roi_array = wwg_array / pb_array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-493-9d08942e1bb0> in <module>
# ----> 1 roi_array = wwg_array / pb_array
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
roi_array
# Out:
# array([  2.54667286,   0.42789243,   4.24384139, ...,   0.2676    ,
#          0.        , 164.58272727])

# %%
roi_list = roi_array.tolist()
roi_list
# Out:
# [2.546672856794934,
#  0.42789242857142856,
#  4.243841388384755,
#  4.153696362776025,
#  6.710167385620915,
#  6.827114,
#  3.2114014166666665,
#  2.18648403,
#  2.9320697433333334,
#  3.9434149054545453,
#  1.4296412618181817,
#  0.9454622363636364,
#  1.028284,
#  2.255681692307692,
#  3.468450503875969,
#  4.560277652,
#  3.470001124,
#  4.068014272,
#  3.740855068,
#  3.84146742,
#  3.782310484,
#  4.939385068,
#  1.612435625,
#  3.4271353782608696,
#  2.5725742521739132,
#  6.746381764444444,
#  4.738736942222222,
#  2.9688867466666666,
#  1.854850168888889,
#  3.444955759090909,
#  1.4248987136363636,
#  2.778310322580645,
#  7.669092390697674,
#  3.042853418604651,
#  3.983427138095238,
#  5.2573289333333335,
#  2.186956885714286,
#  1.5355190761904762,
#  2.6595041400966184,
#  1.7915246731707317,
#  6.74129112,
#  11.041041975,
#  6.212603555,
#  5.24551428,
#  5.106075965,
#  5.34439761,
#  6.07696136,
#  4.311581165,
#  3.97555335,
#  5.12745555,
#  5.552634905,
# ...

# %%
budgets['roi'] = roi_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-494-c86b9d3259ee> in <module>
# ----> 1 budgets['roi'] = roi_list
#
# ~\anaconda3\Conda\envs\learn-env\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\Conda\envs\learn-env\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\anaconda3\Conda\envs\learn-env\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
# ...

# %%
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0         425000000   $760,507,625      2776345279
# 1         410600000   $241,063,875      1045663875
# 2         350000000    $42,762,350       149762350
# 3         330600000   $459,005,868      1403013963
# 4         317000000   $620,181,382      1316721747

# %%
basics_ratings_df = pd.merge(basics,
                            ratings,
                            on = ['tconst'])
